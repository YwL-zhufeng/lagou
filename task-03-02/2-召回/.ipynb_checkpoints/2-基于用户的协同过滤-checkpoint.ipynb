# %% [markdown]
# ## 导包&载入数据集

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tm_online_data/example.txt',header=None)

# %%
df.columns = ['用户ID','物品ID','喜好程度']
df
# Out:
#     用户ID  物品ID  喜好程度
# 0      1     1     4
# 1      1     2     3
# 2      1     5     5
# 3      2     1     5
# 4      2     3     4
# 5      2     5     4
# 6      3     1     4
# 7      3     3     5
# 8      3     4     3
# 9      3     5     4
# 10     4     2     3
# 11     4     6     5
# 12     5     2     4
# 13     5     6     4
# 14     6     3     2
# 15     6     4     4
# 16     6     6     5

# %% [markdown]
# ## 建立关系矩阵

# %%
# 创建矩阵
df_pivot = df.pivot(index='用户ID',columns='物品ID',values='喜好程度') # 重塑数据
df_pivot
# Out:
# 物品ID    1    2    3    4    5    6
# 用户ID
# 1     4.0  3.0  NaN  NaN  5.0  NaN
# 2     5.0  NaN  4.0  NaN  4.0  NaN
# 3     4.0  NaN  5.0  3.0  4.0  NaN
# 4     NaN  3.0  NaN  NaN  NaN  5.0
# 5     NaN  4.0  NaN  NaN  NaN  4.0
# 6     NaN  NaN  2.0  4.0  NaN  5.0

# %% [markdown]
# ## 空值填充、填充为0

# %%
freq = df_pivot.fillna(0)
freq # 格式为dataframe
# Out:
# 物品ID    1    2    3    4    5    6
# 用户ID
# 1     4.0  3.0  0.0  0.0  5.0  0.0
# 2     5.0  0.0  4.0  0.0  4.0  0.0
# 3     4.0  0.0  5.0  3.0  4.0  0.0
# 4     0.0  3.0  0.0  0.0  0.0  5.0
# 5     0.0  4.0  0.0  0.0  0.0  4.0
# 6     0.0  0.0  2.0  4.0  0.0  5.0

# %%
# 转换成数组方便计算
freq_matrix = freq.values
freq_matrix
# Out:
# array([[4., 3., 0., 0., 5., 0.],
#        [5., 0., 4., 0., 4., 0.],
#        [4., 0., 5., 3., 4., 0.],
#        [0., 3., 0., 0., 0., 5.],
#        [0., 4., 0., 0., 0., 4.],
#        [0., 0., 2., 4., 0., 5.]])

# %% [markdown]
# ## 使用余弦相似度计算用户相似度矩阵

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
user_similar_matrix = cosine_similarity(freq_matrix)
user_similar_matrix # 6*6矩阵
# Out:
# array([[1.        , 0.74926865, 0.62667956, 0.21828206, 0.3       ,
#         0.        ],
#        [0.74926865, 1.        , 0.91301651, 0.        , 0.        ,
#         0.1579597 ],
#        [0.62667956, 0.91301651, 1.        , 0.        , 0.        ,
#         0.40368671],
#        [0.21828206, 0.        , 0.        , 1.        , 0.9701425 ,
#         0.63913749],
#        [0.3       , 0.        , 0.        , 0.9701425 , 1.        ,
#         0.52704628],
#        [0.        , 0.1579597 , 0.40368671, 0.63913749, 0.52704628,
#         1.        ]])

# %% [markdown]
# ### 通过热图观测相关性

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(user_similar_matrix,annot=True) # 显示相似度数值
plt.show()

# %%
freq_matrix
# Out:
# array([[4., 3., 0., 0., 5., 0.],
#        [5., 0., 4., 0., 4., 0.],
#        [4., 0., 5., 3., 4., 0.],
#        [0., 3., 0., 0., 0., 5.],
#        [0., 4., 0., 0., 0., 4.],
#        [0., 0., 2., 4., 0., 5.]])

# %%
# 查看用户行为
user_id_action = freq_matrix[2,:]
user_id_action
# Out:
# array([4., 0., 5., 3., 4., 0.])

# %%
# 查看物品4 的所有用户评分
item_id_action = freq_matrix[:,3]
item_id_action
# Out:
# array([0., 0., 3., 0., 0., 4.])

# %% [markdown]
# ## 构建推荐系统指数函数

# %%
# 给第一个用户进行推荐
user_id = 0

# %%
# 提取当前想要推荐用户的评分向量
user_id_action = freq_matrix[user_id]
user_id_action
# Out:
# array([4., 3., 0., 0., 5., 0.])

# %%
# 计算产品3是否应该推荐给这个用户
item_id = 2

# %%
# 所有用户对于产品3的评分向量
freq_matrix[:,item_id]
# Out:
# array([0., 4., 5., 0., 0., 2.])

# %%
# 用户user_id对用户的相似度
user_id_similar = user_similar_matrix[user_id]
user_id_similar
# Out:
# array([1.        , 0.74926865, 0.62667956, 0.21828206, 0.3       ,
#        0.        ])

# %%
# 找到最相似的K个用户的index（除了自己）
k=2

# %%
np.argsort(user_id_similar)
# Out:
# array([5, 3, 4, 2, 1, 0], dtype=int64)

# %%
# 前两个（数组中-3：-1）最相似的用户提取出来
similar_index = np.argsort(user_id_similar)[-(k+1):-1]
similar_index
# Out:
# array([2, 1], dtype=int64)

# %%
# 所有用户对于产品3的评分向量
item_id_action = freq_matrix[:,item_id]
item_id_action
# Out:
# array([0., 4., 5., 0., 0., 2.])

# %%
# 定义两个变量额，存储用户的分数,产品的权重
score = 0 # 分子 用户分数
weight = 0 # 分母 产品权重

# 对相近的k个用户进行遍历
for similar_user_id in similar_index: #[2,1]
    print(similar_user_id)
    
    # 先判断这个用户有没有对这个产品进行评分，如果没有打分，则直接计算下一个用户
    if item_id_action[similar_user_id] != 0:
        # 用户和当前用户的相似度 * 用户对这个产品的打分
        score += user_id_similar[similar_user_id] * item_id_action[similar_user_id] 
        print('用户ID:',similar_user_id,'用户分数之和:',score)
        
        # 计算公式的分母，即所有用户相似度之和
        weight += user_id_similar[similar_user_id]
        print('相似度之和:',weight)

# 相似的k个用户是没有对这个产品进行评分的
if score == 0:
    print(0)
else:
    # 最终推荐指数
    rec_inex = score / weight
    print('最终计算结果，对该产品的推荐指数：',rec_inex)
# Out:
# 2
# 用户ID: 2 用户分数之和: 3.133397807202561
# 相似度之和: 0.6266795614405122
# 1
# 用户ID: 1 用户分数之和: 6.1304724042639815
# 相似度之和: 1.3759482107058674
# 最终计算结果，对该产品的推荐指数： 4.455452869929619

# %%
# 封装成推荐指数函数
def cal_recommend_index(k,user_id,item_id,freq_matrix,user_similar_matrix):
    """函数功能：传入用户ID，产品ID，计算该产品对于用户的推荐指数
    参数：k:取几个最相近用户
          user_id：用户ID：给指定用户进行推荐
          item_id：产品ID
          freq_matrix：评分矩阵
          user_similar_matrix：相似度矩阵    
    """
    # 提取当前想要推荐用户的评分向量
    user_id_action = freq_matrix[user_id]
    
    # 所有用户对于产品3的评分向量
    item_id_action = freq_matrix[:,item_id]
    
    # 用户user_id对所有用户的相似度
    user_id_similar = user_similar_matrix[user_id]
    
    # 前k个（数组中-(k+1)：-1）最相似的用户提取出来
    similar_index = np.argsort(user_id_similar)[-(k+1):-1]
    
    # 定义两个变量额，存储用户的分数,产品的权重
    score = 0 # 分子 用户分数
    weight = 0 # 分母 产品权重

    # 对相近的k个用户进行遍历
    for similar_user_id in similar_index: #[2,1]
        #print(similar_user_id)

        # 先判断这个用户有没有对这个产品进行评分，如果没有打分，则直接计算下一个用户
        if item_id_action[similar_user_id] != 0:
            # 用户和当前用户的相似度 * 用户对这个产品的打分
            score += user_id_similar[similar_user_id] * item_id_action[similar_user_id] 
            #print('用户ID:',similar_user_id,'用户分数之和:',score)

            # 计算公式的分母，即所有用户相似度之和
            weight += user_id_similar[similar_user_id]
            #print('相似度之和:',weight)

    # 相似的k个用户是没有对这个产品进行评分的
    if score == 0:
        print(0)
    else:
        # 最终推荐指数
        rec_index = score / weight
        return rec_index
        #print('最终计算结果，对该产品的推荐指数：',rec_inex)

# %%
cal_recommend_index(k=2,
                    user_id=1,
                    item_id=3,
                    freq_matrix=freq_matrix,
                    user_similar_matrix=user_similar_matrix)
# Out:
# 3.0

# %%
cal_recommend_index(k=3,
                    user_id=0,
                    item_id=2,
                    freq_matrix=freq_matrix,
                    user_similar_matrix=user_similar_matrix)
# Out:
# 4.455452869929619

# %% [markdown]
# ## 构建预测函数

# %%
def cal_recommend_index_matrix(freq_matrix,user_similar_matrix):
    """函数功能：传入参数相似度矩阵和用户评分矩阵，计算返回用户推荐矩阵
    参数：
    freq_matrix：用户评分矩阵
    user_similar_matrix：相似度矩阵
    返回：计算的推荐系统矩阵
    """
    
    user_count = freq_matrix.shape[0] # 获取用户数
    item_count = freq_matrix.shape[1] # 获取商品数
    
    # 构建一个用户数*商品数的空矩阵
    predit_matrix = np.zeros((user_count,item_count))
    
    
    for user_id in range(user_count):
        for item_id in range(item_count):
            
            # 首先判断原来的评分矩阵中有没有值的存在，如果有不需要计算 即买过了不推荐
            if freq_matrix[user_id,item_id] == 0:
                
                # 调用推荐指数函数，返回值填充到predit_matrix对应位置
                predit_matrix[user_id,item_id] = cal_recommend_index(k=3,
                                                                    user_id=user_id,
                                                                    item_id=item_id,
                                                                    freq_matrix=freq_matrix,
                                                                    user_similar_matrix=user_similar_matrix)
    return predit_matrix

# %%
predit_matrix = cal_recommend_index_matrix(freq_matrix,user_similar_matrix)
predit_matrix
# Out:
# array([[0.        , 0.        , 4.45545287, 3.        , 0.        ,
#         4.        ],
#        [0.        , 3.        , 0.        , 3.14749133, 0.        ,
#         5.        ],
#        [0.        , 3.        , 0.        , 0.        , 0.        ,
#         5.        ],
#        [4.        , 0.        , 2.        , 4.        , 5.        ,
#         0.        ],
#        [4.        , 0.        , 2.        , 4.        , 5.        ,
#         0.        ],
#        [4.        , 3.45194102, 0.        , 0.        , 4.        ,
#         0.        ]])

# %%
# 将推荐矩阵转换成DataFrame
recommend_df = pd.DataFrame(predit_matrix,index=df_pivot.index,columns=df_pivot.columns)
recommend_df
# Out:
# 物品ID    1         2         3         4    5    6
# 用户ID
# 1     0.0  0.000000  4.455453  3.000000  0.0  4.0
# 2     0.0  3.000000  0.000000  3.147491  0.0  5.0
# 3     0.0  3.000000  0.000000  0.000000  0.0  5.0
# 4     4.0  0.000000  2.000000  4.000000  5.0  0.0
# 5     4.0  0.000000  2.000000  4.000000  5.0  0.0
# 6     4.0  3.451941  0.000000  0.000000  4.0  0.0

# %%
recommend_df.stack()
# Out:
# 用户ID  物品ID
# 1     1       0.000000
#       2       0.000000
#       3       4.455453
#       4       3.000000
#       5       0.000000
#       6       4.000000
# 2     1       0.000000
#       2       3.000000
#       3       0.000000
#       4       3.147491
#       5       0.000000
#       6       5.000000
# 3     1       0.000000
#       2       3.000000
#       3       0.000000
#       4       0.000000
#       5       0.000000
#       6       5.000000
# 4     1       4.000000
#       2       0.000000
#       3       2.000000
#       4       4.000000
#       5       5.000000
#       6       0.000000
# 5     1       4.000000
#       2       0.000000
#       3       2.000000
#       4       4.000000
#       5       5.000000
#       6       0.000000
# 6     1       4.000000
#       2       3.451941
#       3       0.000000
#       4       0.000000
#       5       4.000000
#       6       0.000000
# dtype: float64

# %%
recommend_df_result = recommend_df.stack().reset_index()
recommend_df_result
# Out:
#     用户ID  物品ID         0
# 0      1     1  0.000000
# 1      1     2  0.000000
# 2      1     3  4.455453
# 3      1     4  3.000000
# 4      1     5  0.000000
# 5      1     6  4.000000
# 6      2     1  0.000000
# 7      2     2  3.000000
# 8      2     3  0.000000
# 9      2     4  3.147491
# 10     2     5  0.000000
# 11     2     6  5.000000
# 12     3     1  0.000000
# 13     3     2  3.000000
# 14     3     3  0.000000
# 15     3     4  0.000000
# 16     3     5  0.000000
# 17     3     6  5.000000
# 18     4     1  4.000000
# 19     4     2  0.000000
# 20     4     3  2.000000
# 21     4     4  4.000000
# 22     4     5  5.000000
# 23     4     6  0.000000
# 24     5     1  4.000000
# 25     5     2  0.000000
# 26     5     3  2.000000
# 27     5     4  4.000000
# 28     5     5  5.000000
# 29     5     6  0.000000
# 30     6     1  4.000000
# 31     6     2  3.451941
# 32     6     3  0.000000
# 33     6     4  0.000000
# 34     6     5  4.000000
# 35     6     6  0.000000

# %%
recommend_df_result.rename(columns={0:'推荐指数'},inplace=True) # 替换列名

# %%
recommend_df_result
# Out:
#     用户ID  物品ID      推荐指数
# 0      1     1  0.000000
# 1      1     2  0.000000
# 2      1     3  4.455453
# 3      1     4  3.000000
# 4      1     5  0.000000
# 5      1     6  4.000000
# 6      2     1  0.000000
# 7      2     2  3.000000
# 8      2     3  0.000000
# 9      2     4  3.147491
# 10     2     5  0.000000
# 11     2     6  5.000000
# 12     3     1  0.000000
# 13     3     2  3.000000
# 14     3     3  0.000000
# 15     3     4  0.000000
# 16     3     5  0.000000
# 17     3     6  5.000000
# 18     4     1  4.000000
# 19     4     2  0.000000
# 20     4     3  2.000000
# 21     4     4  4.000000
# 22     4     5  5.000000
# 23     4     6  0.000000
# 24     5     1  4.000000
# 25     5     2  0.000000
# 26     5     3  2.000000
# 27     5     4  4.000000
# 28     5     5  5.000000
# 29     5     6  0.000000
# 30     6     1  4.000000
# 31     6     2  3.451941
# 32     6     3  0.000000
# 33     6     4  0.000000
# 34     6     5  4.000000
# 35     6     6  0.000000

# %% [markdown]
# ### 构建最终的推荐函数

# %%
recommend_df_group = recommend_df_result.groupby(by='用户ID')
recommend_df_group

# %%
def get_topk(group,n):
    """根据分组后的推荐指数矩阵排序得到最高几个
    参数：
    group：分组后的推荐指数矩阵
    n:个数
    """
    return group.sort_values('推荐指数',ascending = False)[:n]

# %%
get_topk(recommend_df_result.loc[:5],3)
# Out:
#    用户ID  物品ID      推荐指数
# 2     1     3  4.455453
# 5     1     6  4.000000
# 3     1     4  3.000000

# %%
topk = recommend_df_group.apply(get_topk,3)
topk
# Out:
#          物品ID      推荐指数
# 用户ID
# 1    2      3  4.455453
#      5      6  4.000000
#      3      4  3.000000
# 2    11     6  5.000000
#      9      4  3.147491
#      7      2  3.000000
# 3    17     6  5.000000
#      13     2  3.000000
#      12     1  0.000000
# 4    22     5  5.000000
#      18     1  4.000000
#      21     4  4.000000
# 5    28     5  5.000000
#      24     1  4.000000
#      27     4  4.000000
# 6    30     1  4.000000
#      34     5  4.000000
#      31     2  3.451941

# %%
topk.index = topk.index.droplevel(1)
topk
# Out:
#       物品ID      推荐指数
# 用户ID
# 1        3  4.455453
# 1        6  4.000000
# 1        4  3.000000
# 2        6  5.000000
# 2        4  3.147491
# 2        2  3.000000
# 3        6  5.000000
# 3        2  3.000000
# 3        1  0.000000
# 4        5  5.000000
# 4        1  4.000000
# 4        4  4.000000
# 5        5  5.000000
# 5        1  4.000000
# 5        4  4.000000
# 6        1  4.000000
# 6        5  4.000000
# 6        2  3.451941

# %%
def get_recommendation(predict_matrix,n=3):
    recommend_df = pd.DataFrame(predit_matrix,index=df_pivot.index,columns=df_pivot.columns)
    
    # 将数据进行转换
    recommend_df_result = recommend_df.stack().reset_index()
    
    # 对列名进行修改
    recommend_df_result.rename(columns={0:'推荐指数'},inplace=True) # 替换列名
    
    # 根据用户ID进行分组
    recommend_df_group = recommend_df_result.groupby(by='用户ID')
    
    # 得到分组后的前几条数据
    topk = recommend_df_group.apply(get_topk,n=3)
    
    # 删除用户ID列
    topk = topk.drop(['用户ID'],axis=1)
    
    # 删除多余索引
    topk.index = topk.index.droplevel(1)
    
    # 索引重排
    topk.reset_index(inplace=True)
    
    return topk

# %%
get_recommendation(predit_matrix,3)
# Out:
#     用户ID  物品ID      推荐指数
# 0      1     3  4.455453
# 1      1     6  4.000000
# 2      1     4  3.000000
# 3      2     6  5.000000
# 4      2     4  3.147491
# 5      2     2  3.000000
# 6      3     6  5.000000
# 7      3     2  3.000000
# 8      3     1  0.000000
# 9      4     5  5.000000
# 10     4     1  4.000000
# 11     4     4  4.000000
# 12     5     5  5.000000
# 13     5     1  4.000000
# 14     5     4  4.000000
# 15     6     1  4.000000
# 16     6     5  4.000000
# 17     6     2  3.451941
